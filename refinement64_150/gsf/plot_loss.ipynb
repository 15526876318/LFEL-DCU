# %%
import matplotlib.pyplot as plt 
import numpy as np 

def get_train_val_info(f1):
    train = []
    val = []
    acc_t = []
    acc_v = []
    with open (f1,'r') as t:
        lines = t.readlines()
        for line in lines:
            try:
                a,_,loss,acc = line.split(" ")
            except:
                continue
            #print(a)
            if a =="train:":
                train.append(np.round(float(loss),4))
                acc_t.append(np.round(float(acc),4))
            elif a == "val:":
                val.append(np.round(float(loss),4))
                acc_v.append(np.round(float(acc),4))
    return train,val,acc_t,acc_v

def plot_loss_acc(train,val,acc_t,acc_v):
    font = 20
    fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(13,5))
    ax = axes.flatten()
    ax[0].plot( list(range(len(train))),train,label = 'train', color='blue',linewidth=1.0,linestyle='-')
    ax[0].plot( list(range(len(train))),val,label = 'validation', color='red',linewidth=1.0,linestyle='-')
    ax[1].plot( list(range(len(train))),acc_t,label = 'train', color='blue',linewidth=1.0,linestyle='-')
    ax[1].plot( list(range(len(train))),acc_v,label = 'validation', color='red',linewidth=1.0,linestyle='-')
    ax[0].set_ylabel("Loss", fontsize=font)
    ax[1].set_ylabel("ACC", fontsize=font)
    ax[0].set_xlabel("EPOCH", fontsize=font)
    ax[1].set_xlabel("EPOCH", fontsize=font)
    ax[0].legend(fontsize=font)
    ax[1].legend(fontsize=font)
    plt.show()
    plt.savefig("loss.png")

# %%
f1 = "tsf16_seq0_208_256_21_epoch50_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "tsf16_seq0_208_256_21_epoch30_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "fc416_seq0_208_256_21_epoch30_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "fc416_seq0_208_256_21_epoch40_0.2.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "fc416_seq0_208_256_21_epoch50_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "fc416_seq0_208_256_21_epoch80_0.2.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "fc4SGD16_seq1_560_1024_21_epoch50_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "tsf16_seq1_560_512_21_epoch50_0.1.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)

# %%
f1 = "../gsf_JEM/JEMSGD16_770_512_21_E60_0.1_iter6_gw0_ct0_sp_norm.log"
train,val,acc_t,acc_v = get_train_val_info(f1)
plot_loss_acc(train,val,acc_t,acc_v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-557e689d12f2> in <module>
#       1 f1 = "../gsf_JEM/JEMSGD16_770_512_21_E60_0.1_iter6_gw0_ct0_sp_norm.log"
# ----> 2 train,val,acc_t,acc_v = get_train_val_info(f1)
#       3 plot_loss_acc(train,val,acc_t,acc_v)
#
# <ipython-input-1-aed101debcd8> in get_train_val_info(f1)
#      10         lines = t.readlines()
#      11         for line in lines:
# ---> 12             a,_,loss,acc = line.split(" ")
#      13             #print(a)
#      14             if a =="train:":
#
# ValueError: not enough values to unpack (expected 4, got 2)
